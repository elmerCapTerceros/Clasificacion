# %% [markdown]
# ## Limpiesa de images

# %% [markdown]
# ### Metal

# %%
import os
from PIL import Image

def tranformarCarpeta(ruta_destino,ruta_origen):
    # Crear carpeta de salida
    tamaño_salida = (224, 224)
    os.makedirs(ruta_destino, exist_ok=True)

    # Recorrer cada clase (carpeta)
    for clase in os.listdir(ruta_origen):
        

    for nombre_img in os.listdir(ruta_clase):
        ruta_img = os.path.join(ruta_clase, nombre_img)
        try:
            with Image.open(ruta_img) as img:
                # Convertir a escala de grises y redimensionar
                img_gris = img.convert("L").resize(tamaño_salida)
                # Guardar
                img_gris.save(os.path.join(ruta_salida_clase, nombre_img))
        except Exception as e:
            print(f"Error con {ruta_img}: {e}")



# Configuración
carpeta_raiz="Garbage classification/"
carpeta_transformacion="metal"
ruta_origen = carpeta_raiz+carpeta_transformacion
ruta_destino = carpeta_raiz+"tranformacion_"+carpeta_transformacion
tranformarCarpeta(ruta_destino=ruta_destino,ruta_origen=ruta_origen)
# Out:
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# no encontro
# ...
